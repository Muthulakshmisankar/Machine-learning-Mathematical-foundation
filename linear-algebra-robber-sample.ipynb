# %%
import numpy as np
import matplotlib.pyplot as plt
t= np.linspace(0, 40 , 10)
print(t)
# Out:
# [ 0.          4.44444444  8.88888889 13.33333333 17.77777778 22.22222222
#  26.66666667 31.11111111 35.55555556 40.        ]

# %% [markdown]
# Distance = speed * time

# %% [markdown]
# Distance travelled by robber

# %%
d_r = 2.5 * t 
print(d_r)
# Out:
# [  0.          11.11111111  22.22222222  33.33333333  44.44444444
#   55.55555556  66.66666667  77.77777778  88.88888889 100.        ]

# %% [markdown]
# Distance travelled by sheriff

# %%
d_s = 3 * (t - 5)
print(d_s)
# Out:
# [-15.          -1.66666667  11.66666667  25.          38.33333333
#   51.66666667  65.          78.33333333  91.66666667 105.        ]

# %% [markdown]
# Figure Plots

# %%
fig, ax = plt.subplots()
plt.title('A bank robber caught')
plt.xlabel('Time (in mins)')
plt.ylabel('distance (in km)')
ax.set_xlim([0, 40])
ax.set_ylim([0, 100])
ax.plot(t,d_r, c='green')
ax.plot(t, d_s , c='brown')
plt.axvline(x=30 , color ='purple' , linestyle='--')
_=plt.axhline(y=75 , color = 'purple' , linestyle = '--')
